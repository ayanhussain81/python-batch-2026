# %% [markdown]
# # Lists

# %%
# data type 
# collection of values

# %%
# ayesha 

ayesha_maths = 90
ayesha_computer = 80 
ayesha_python = 70 

# subjects = 5 
# students = 50 
# 50 * 5 = 250 
print(ayesha_maths)
# Out:
# 90

# %%
# sunil 
sunil_maths = 40
sunil_computer = 100
sunil_python = 80

# %%
print(sunil_maths)
print(ayesha_maths)
# Out:
# 40
# 90

# %%
# collection of values 

ayesha_marks = [90,80,70,50,75]
# [] -> square brackets 

# starts with []
# seperate values with ,

print(ayesha_marks)
# Out:
# [90, 80, 70, 50, 75]

# %%
subjects = ['Maths', 'Computer','Python','English','Biology']
print(subjects)
# Out:
# ['Maths', 'Computer', 'Python', 'English', 'Biology']

# %%
# list indexing 
# [0,1,2,3,4,5,6,7,8]
# from left to right 

subjects = ['Maths', 'Computer','Python','English','Biology']
# maths index - 0 
# computer index - 1
# python - 2
# english - 3
# biology - 4

# total index = 5 -1 = 4

print(subjects[0])
# Out:
# Maths

# %%
print(subjects[4])
# Out:
# Biology

# %%
numbers = [1,2,3,4,5,6]
print(numbers[2])
print(numbers[5])

# 1 value index = 0 
# 2 value index = 1
# 3 index = 2
# Out:
# 3
# 6

# %%
 # negative indexing  Right to left 
subjects = ['Maths', 'Computer','Python','English','Biology']
# Biology =  -1 
# english = 2

#nge index=[-5,-4,-3,-2,-1]
# 
print(subjects[-1])  
print(subjects[4])
# Out:
# Biology
# Biology

# %% [markdown]
# Append

# %%
# append - add value at the end
students = ['Ayan', 'Aliza','Dawood']

# sarfaraz 
students.append("Sarafaz")
print(students)
# Out:
# ['Ayan', 'Aliza', 'Dawood', 'Sarafaz']

# %%
students.append("Hussain")

# %%
print(students)
# Out:
# ['Ayan', 'Aliza', 'Dawood', 'Sarafaz', 'Hussain']

# %%
print(students[-1])
print(students[2])
# Out:
# Hussain
# Dawood

# %%
# hw - how to add values at start or at specific index 
# insert and remove 
# difference between insert & append 
# difference between remove & pop

# %% [markdown]
# # Pop

# %%
# removes value from the end 
students.pop() # By default [-1]
# Out:
# 'Hussain'

# %%
print(students)
# Out:
# ['Ayan', 'Aliza', 'Dawood', 'Sarafaz']

# %%
students.pop()
print(students)
# Out:
# ['Ayan', 'Aliza', 'Dawood']

# %%
students.pop(0)
print(students)
# Out:
# ['Aliza', 'Dawood']

# %%
students = ['Ayan', 'Aliza','Dawood']
students.pop(1)
print(students)
# Out:
# ['Ayan', 'Dawood']

# %%
students.pop(5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 students.pop(5)
#
# IndexError: pop index out of range

# %%
subjects = ['Maths', 'Computer','Python','English','Biology']
print(subjects[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 2
#       1 subjects = ['Maths', 'Computer','Python','English','Biology']
# ----> 2 print(subjects[10])
#
# IndexError: list index out of range

# %%
# list supports multiple datatypes in one list 

bio_data = ['Ayan', 'Hussain',50, 5.10, True]
print(bio_data)
# Out:
# ['Ayan', 'Hussain', 50, 5.1, True]
