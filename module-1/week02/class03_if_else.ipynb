# %% [markdown]
# # If - Else

# %%
# Based on conditions 
# kids youtube age limit 
# greater then 10 and less 18 

# Syntax 

# if condition:
#     code logic
# else:
#     code logic

# %%
# agr bacha pass hota hai then next class else same class

# %%
age = int(input("Enter your age"))

if age > 10 and age < 18 :
    print("Yes! your are eligible....")
else:
    print("No! you are not eligible...")
# Out:
# No! you are not eligible...

# %%
# Students Grade Calculations 

marks = int(input("Enter your marks: "))

if marks >= 90:
    print("Grade A+")
elif marks >= 80  and marks < 90:
    print("Grade: A")
elif marks >= 70 and marks < 80:
    print("Grade B")
else:
    print("Grade F")
# Out:
# Grade F

# %%
# checking a number 
# if positive number then print positive or print negative else print zero 

number = int(input("enter a number"))

if number > 0:
   print("positive number")

elif number < 0:
   print("negative number")

else:
    print("Zero")
# Out:
# Zero

# %%
# Nested If - Else

# we have logging systesm
# 1 for students 
# 2 for teachers

logged_in = False
is_teacher = False

if logged_in:
    print("Logged In")

    if is_teacher:  # nested if 
        print("welcome, teacher!")
    else: 
        print("Welcome, Student")

else: # first if ka else hai
    print("Please Login ")
# Out:
# Please Login

# %%
# weekend lazmi 
    # agr sunday to ocean 
    # agr saturday then we will go for a cricket match 

is_weekend = True # true/false
is_sunday = True 

if is_weekend:
    print("Yeahhh weeekends!!!!")

    if is_sunday:
        print("Yeahhhh, we will go to Ocean!!")
    else:
        print("Today is Saturday, Cricket day, lets gooooo........")
else:
    print("Weekdaysss!!!!!")
# Out:
# Yeahhh weeekends!!!!
# Yeahhhh, we will go to Ocean!!

# %%
is_weekend = False # true/false
is_sunday = False 

if is_weekend:
    print("Yeahhh weeekends!!!!")

    if is_sunday:
        print("Yeahhhh, we will go to Ocean!!")
    else:
        print("Today is Saturday, Cricket day, lets gooooo........")
else:
    print("Weekdaysss!!!!!")
# Out:
# Weekdaysss!!!!!

# %%
# username - 
# password - 

# take two inputs user name & password
# agr same # agr wrong user name # wrong password 


correct_username = "admin"
correct_password = "123"
username = input("Enter username: ")
password = input("Enter password: ")

if username == correct_username and password  == correct_password:
    print("Login Successful!")
elif username != correct_username:
    print("Wrong username.")
else:
    print("Wrong password.")
# Out:
# Login Successful!

# %%
players = ['Amir', 'Watson', 'Starc','Ayan']

if 'Ayan' in players:
    print("start booking your flights.....")
else:
    print("No ....")
# Out:
# start booking your flights.....
